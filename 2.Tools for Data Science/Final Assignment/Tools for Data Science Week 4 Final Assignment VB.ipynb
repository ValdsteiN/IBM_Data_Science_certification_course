# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# **Vlad Borysenko**

# %% [markdown]
# Graduate student

# %% [markdown]
# *I am interested in Data Science as it will be helpful in my job search, it is the key to the future and understanding of the world and it is simply interesting*

# %% [markdown]
# ### The following code let's you imagine yourself being a Luke Skywalker when he finds the truth.

# %%
def father(name):
    #print(f'{name.title()}, I am your father!')
    return name.title() + ", I am your father!"
    
father("Amy")
# Out:
# 'Amy, I am your father!'

# %% [markdown]
# #### Shopping List
# * Butter
# * Lemon
# * Milk
#
# #### Python code
# ```python
# for x in range(3):
#     print("Hooray!")
# ```
#
# #### Block quote with a hyperlink
# > “The universe has a beginning, but no end. — Infinity. Stars, too, have their own beginnings, but their own power results in their destruction. — Finite.” – [**Rintaro Okabe**](https://www.imdb.com/title/tt1910272/)
